# %%
#Import Libraries.
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#Load data.
data = pd.read_csv('/content/drive/MyDrive/Coding Dojo/Codes/Week3/catsvdogs.csv')

# %%
plt.bar(data['Location'], data['Dog Population (in 1000)'])
plt.bar(data['Location'], data['Cat Population'])
plt.xticks(rotation = 90);
